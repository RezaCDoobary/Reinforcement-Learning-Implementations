# %%
import environments
import pandas as pd
import numpy as np
from collections import deque
from library import *

# %% [markdown]
# # gym - copy-v0

# %%
env1 = environments.environment_gym('Copy-v0')
env = environments.env_wrapper(env1)
n_actions = 20

# %%
#random policy
policy = random()
Q = defaultdict(lambda: np.zeros(n_actions))
mean_scores, score, moving_window = play(env, Q, 5000, policy)
moving_window = moving_window[5:]
print('max',max(moving_window))
plt.plot(moving_window)
plt.show()
# Out:
#  Episode [4999/5000]max 0.0

# %%
policy = random()
Q_class = update_vanilla_Q(n_actions, gamma = 1.0)
mr = MC(env, policy, Q_class,5000, generate_episode, stopping = 25)
# Out:
# Episode [5000/5000] with mean reward -0.205

# %%
policy = maximum()
mean_scores, score, moving_window = play(env, Q_class.Q, 5000, policy)
moving_window = moving_window[5:]
print('max',max(moving_window))
plt.plot(moving_window)
plt.show()
# Out:
#  Episode [4999/5000]max 1.215

# %%
eps = epsilon(eps_start = 1.0, eps_decay = 0.99, eps_min = 0.1)
policy = epsilon_greedy(eps,200)
Q_class = update_control_Q(n_actions,alpha = 0.2, gamma = 1.0)
mr = MC(env, policy, Q_class, 5000, generate_episode, stopping = 25)
# Out:
# Episode [5000/5000] with mean reward 0.08

# %%
policy = maximum()
mean_scores, score, moving_window = play(env, Q_class.Q, 5000, policy)
moving_window = moving_window[5:]
print('max',max(moving_window))
plt.plot(moving_window)
plt.show()
# Out:
#  Episode [4999/5000]max 2.065

# %% [markdown]
# # Frozen Lake

# %%
env1 = environments.environment_gym('FrozenLake-v0')
env = environments.env_wrapper(env1)
n_actions = 4

# %%
#random policy
policy = random()
Q = defaultdict(lambda: np.zeros(n_actions))
mean_scores, score, moving_window = play(env, Q, 5000, policy)
moving_window = moving_window[5:]
print('max',max(moving_window))
plt.plot(moving_window)
plt.show()
# Out:
#  Episode [4999/5000]max 0.06

# %%
policy = random()
Q_class = update_vanilla_Q(n_actions, gamma = 1.0)
mr = MC(env, policy, Q_class,5000, generate_episode, stopping = 25)
# Out:
# Episode [5000/5000] with mean reward 0.0

# %%
policy = maximum()
mean_scores, score, moving_window = play(env, Q_class.Q, 5000, policy)
moving_window = moving_window[5:]
print('max',max(moving_window))
plt.plot(moving_window)
plt.show()
# Out:
#  Episode [4999/5000]max 0.3333333333333333

# %%
eps = epsilon(eps_start = 1.0, eps_decay = 0.99, eps_min = 0.1)
policy = epsilon_greedy(eps,200)
Q_class = update_control_Q(n_actions,alpha = 0.2, gamma = 1.0)
mr = MC(env, policy, Q_class, 5000, generate_episode, stopping = 25)
# Out:
# Episode [5000/5000] with mean reward 0.01

# %%
policy = maximum()
mean_scores, score, moving_window = play(env, Q_class.Q, 5000, policy)
moving_window = moving_window[5:]
print('max',max(moving_window))
plt.plot(moving_window)
plt.show()
# Out:
#  Episode [4999/5000]max 0.17

# %% [markdown]
# # Blackjack

# %%
env1 = environments.environment_gym('Blackjack-v0')
env = environments.env_wrapper(env1)
n_actions = 2

# %%
#random policy
policy = random()
Q = defaultdict(lambda: np.zeros(n_actions))
mean_scores, score, moving_window = play(env, Q, 5000, policy)
moving_window = moving_window[5:]
print('max',max(moving_window))
plt.plot(moving_window)
plt.show()
# Out:
#  Episode [4999/5000]max -0.09

# %%
policy = random()
Q_class = update_vanilla_Q(n_actions, gamma = 1.0)
mr = MC(env, policy, Q_class,5000, generate_episode, stopping = 1.0)
# Out:
# Episode [5000/5000] with mean reward -0.32

# %%
policy = maximum()
mean_scores, score, moving_window = play(env, Q_class.Q, 5000, policy)
moving_window = moving_window[5:]
print('max',max(moving_window))
plt.plot(moving_window)
plt.show()
# Out:
#  Episode [4999/5000]max 0.13

# %%
eps = epsilon(eps_start = 1.0, eps_decay = 0.99, eps_min = 0.1)
policy = epsilon_greedy(eps,200)
Q_class = update_control_Q(n_actions,alpha = 0.2, gamma = 1.0)
mr = MC(env, policy, Q_class, 5000, generate_episode, stopping = 1.0)
# Out:
# Episode [5000/5000] with mean reward -0.34

# %%
policy = maximum()
mean_scores, score, moving_window = play(env, Q_class.Q, 5000, policy)
moving_window = moving_window[5:]
print('max',max(moving_window))
plt.plot(moving_window)
plt.show()
# Out:
#  Episode [4999/5000]max 0.18181818181818182
